# %%
password = input("Enter your password,User")
if(password) == "Python":
    print("Hello, User")
else: print("Wrong password, try again")
# Out:
# Hello, User

# %%
cmd = input("mistysh")
if (cmd) == "echo":
    print("What do you want to echo ")
    echo = input()
    print(echo)

elif (cmd) == "ls":
        print("ls is not implemented yet")
elif (cmd) == "mistyfetch":
            print("fetching info...")
            mistyfetch = "mistysh alpha v0.1"
            print(mistyfetch)
# Out:
# ls is not implemented yet
